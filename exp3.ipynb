# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 3A

# %%
data={'A':[1,2,np.nan],'B':[4,np.nan,np.nan]}
df=pd.DataFrame(data)
print(df.isna())
df_clean=df.dropna()
df_filled=df.fillna(0)
print()
print(df_clean)
print()
print(df_filled)
# Out:
#        A      B
# 0  False  False
# 1  False   True
# 2   True   True
#
#      A    B
# 0  1.0  4.0
#
#      A    B
# 0  1.0  4.0
# 1  2.0  0.0
# 2  0.0  0.0

# %% [markdown]
# # 3B

# %%
df=pd.DataFrame({'gender':['male','female']})
df['gender_num']=df['gender'].map({'male':1,'female':0})
df_renamed=df.rename(columns={'gender':'Gender'})
print(df_renamed)
# Out:
#    Gender  gender_num
# 0    male           1
# 1  female           0

# %% [markdown]
# # 3C

# %%
data=pd.DataFrame(np.random.randn(100,3))
outliers=(data>3)|(data<-3)
print(outliers.sum())
data
# Out:
# 0    0
# 1    0
# 2    0
# dtype: int64
#            0         1         2
# 0   0.560052  0.252260 -0.133825
# 1   0.186794  0.226228  0.867284
# 2   0.302773  0.313975  1.227911
# 3   0.100393  1.010451  1.319555
# 4   0.121541  0.876219  1.321859
# ..       ...       ...       ...
# 95 -1.146977 -0.345179  0.924955
# 96 -0.887499  1.129423  0.360017
# 97 -0.092827  1.755993  0.191140
# 98  0.332147 -0.816877  2.638992
# 99  0.637932  0.330189  1.658630
#
# [100 rows x 3 columns]

# %% [markdown]
# # 3d

# %%
import re

# %%
txt="this is \t a \n test"
split_txt=re.split(r'\st',txt)
print(split_txt)
# Out:
# ['this is \t a \n', 'est']
